# %%
from itertools import count
from urllib import request
import scapy.all as scapy

# a= scapy.ARP()
# print(a.show())
capture = scapy.sniff(filter='tcp',count=25, iface = 'NPF_Loopback')
# capture.hexdump()

scapy.wrpcap("t.pcap",capture)
# def func(packet):

# %%
import pyshark
cap = pyshark.FileCapture('mycapture.cap')
cap
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Abdul Rasheed\Desktop\AI4OT\Scrapy\test.ipynb Cell 2 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Abdul%20Rasheed/Desktop/AI4OT/Scrapy/test.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import pyshark
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Abdul%20Rasheed/Desktop/AI4OT/Scrapy/test.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> cap = pyshark.FileCapture('mycapture.cap')
#       <a href='vscode-notebook-cell:/c%3A/Users/Abdul%20Rasheed/Desktop/AI4OT/Scrapy/test.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> cap
#
# ...
